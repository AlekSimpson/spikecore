# %%
from spike_engine_cuda import SpikeEngineCUDA
from topologies import square_torus
import cupy as cp

print("start")
N = 25
print("starting engine")
engine = SpikeEngineCUDA(square_torus(N), (N, N))
engine.set_input_neurons([200, 500])
lifetime = 1000
inputspikes = cp.ones((lifetime, 2))

engine.start_static_record(inputspikes, lifetime, "logtest1.spire")
# Out:
# start
# starting engine
# spike engine initializing
# constants loaded
# Constructing weight matrix...
# Weights constructed.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:21<00:00, 47.54it/s]
# Recording saved: logtest1.spire
